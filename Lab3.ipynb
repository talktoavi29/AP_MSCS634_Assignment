# %%
# Name: Abhishek Pandey
# Course: Advanced Big Data and Data Mining (MSCS-634-M20)
# Lab 3: Clustering Analysis Using K-Means and K-Medoids Algorithms

# %%
# !pip -q install pyclustering
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 41.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from sklearn.datasets import load_wine
import pandas as pd
from sklearn.metrics import adjusted_rand_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

wine = load_wine()
X = wine.data
y = wine.target

df = pd.DataFrame(X, columns=wine.feature_names)
df['class'] = y

df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  class
# ...

# %%
df['class'].value_counts()
# Out:
# class
# 1    71
# 0    59
# 2    48
# Name: count, dtype: int64

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_scaled[:5]
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, -1.16959318,  1.91390522,
#          0.80899739,  1.03481896, -0.65956311,  1.22488398,  0.25171685,
#          0.36217728,  1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, -2.49084714,  0.01814502,
#          0.56864766,  0.73362894, -0.82071924, -0.54472099, -0.29332133,
#          0.40605066,  1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, -0.2687382 ,  0.08835836,
#          0.80899739,  1.21553297, -0.49840699,  2.13596773,  0.26901965,
#          0.31830389,  0.78858745,  1.39514818],
#        [ 1.69154964, -0.34681064,  0.4879264 , -0.80925118,  0.93091845,
#          2.49144552,  1.46652465, -0.98187536,  1.03215473,  1.18606801,
#         -0.42754369,  1.18407144,  2.33457383],
#        [ 0.29570023,  0.22769377,  1.84040254,  0.45194578,  1.28198515,
#          0.80899739,  0.66335127,  0.22679555,  0.40140444, -0.31927553,
# ...

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans_labels = kmeans.fit_predict(X_scaled)

kmeans_labels[:10]
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2], dtype=int32)

# %%
kmeans_silhouette = silhouette_score(X_scaled, kmeans_labels)
kmeans_silhouette
# Out:
# 0.2848589191898987

# %%
kmeans_ari = adjusted_rand_score(y, kmeans_labels)
kmeans_ari
# Out:
# 0.8974949815093207

# %%
import numpy as np
from pyclustering.cluster.kmedoids import kmedoids
from sklearn.metrics import silhouette_score, adjusted_rand_score

X_scaled_np = np.array(X_scaled)

np.random.seed(42)
initial_medoids = np.random.choice(len(X_scaled_np), 3, replace=False).tolist()

kmed = kmedoids(X_scaled_np, initial_medoids, data_type='points')
kmed.process()

clusters = kmed.get_clusters() 
medoid_indices = kmed.get_medoids()  

kmedoids_labels = np.empty(len(X_scaled_np), dtype=int)
for cluster_id, idxs in enumerate(clusters):
    kmedoids_labels[idxs] = cluster_id

kmedoids_silhouette = silhouette_score(X_scaled_np, kmedoids_labels)
kmedoids_ari = adjusted_rand_score(y, kmedoids_labels)

kmedoids_silhouette, kmedoids_ari, medoid_indices
# Out:
# (0.2676220575785755, 0.7411365432162113, [35, 106, 148])

# %%
kmedoids_silhouette = silhouette_score(X_scaled, kmedoids_labels)
kmedoids_silhouette
# Out:
# 0.2676220575785755

# %%
kmedoids_ari = adjusted_rand_score(y, kmedoids_labels)
kmedoids_ari
# Out:
# 0.7411365432162113
